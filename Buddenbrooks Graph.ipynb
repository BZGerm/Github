# %%
# %load_ext hierarchymagic
# Out:
# The hierarchymagic extension is already loaded. To reload it, use:
#   %reload_ext hierarchymagic

# %%
# %reload_ext hierarchymagic

# %%
# %%dot -f svg
# digraph "My graph" {
#     father [label=father, shape=box, color=red, style=bold]
#     mother [label=mother, shape=box, color=blue, style=bold]
#     {rank=same; Johann, Antoinette }
#     {rank=same; Jean, Bethsy }
#     {rank=same; Thomas, Gerda }
#     {rank=same; Erika, Hugo }
#     Johann -> Josephine [arrowhead=none, style=dotted]
#     Johann -> Gotthold [color=red, style=bold]
#     Josephine -> Gotthold [color=blue, style=bold]
#     Josephine [label="Josephine
#  (deceased)"]
#     Johann -> Antoinette [arrowhead=none, style=bold, label=married]
#     Johann -> Jean [color=red, style=bold]
#     Antoinette -> Jean [color=blue, style=bold]
#     Lebrecht -> Bethsy [color=red, style=bold]
#     Lebrecht -> Justus [color=red, style=bold]
#     Justus -> Jakob [color=red, style=bold]
#     Justus -> Juergen [color=red, style=bold]
#     Jean -> Bethsy [arrowhead=none, style=bold, label=married]
#     Jean -> Thomas [color=red, style=bold]
#     Jean -> Christian [color=red, style=bold]
#     Jean -> Antonie [color=red, style=bold]
#     Jean -> Clara [color=red, style=bold]
#     Bethsy -> Thomas [color=blue, style=bold]
#     Bethsy -> Christian [color=blue, style=bold]
#     Bethsy -> Antonie [color=blue, style=bold]
#     Bethsy -> Clara [color=blue, style=bold]
#     Thomas -> Gerda [arrowhead=none, style=bold, label=married]
#     Thomas -> Hanno [color=red, style=bold]
#     Gerda -> Hanno [color=blue, style=bold]
#     Christian -> Aline [arrowhead=none, style=bold, label=couple]
#     Antonie -> Bendix [arrowhead=none, style=bold, label=divorced]
#     Antonie -> Erika [color=blue, style=bold]
#     Bendix -> Erika [color=red, style=bold]
#     Antonie -> Alois [arrowhead=none, style=bold, label=divorced]
#     Erika -> Hugo [arrowhead=none, style=bold, label=married]
#     Erika -> Elisabeth [color=blue, style=bold]
#     Hugo -> Elisabeth [color=red, style=bold]
# }
